# %% [markdown]
# ## feature engineering:
# - smoothness of oscillator curves
# - smoothness of price curves
# - smoothness of MACD curves
# - price percentage change compared to day #0
# - daily price movement (percentage change %)
# - oscillator absolute values change compared to day #40
# - MACD values normalized

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re 
import os
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_score, classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.preprocessing import normalize
import time

# %%
from xgboost import XGBClassifier

# %%
file_path = '../data/buy/'

timeframe = '3days'
if timeframe == '3days':
    bar_cnt = 41
elif timeframe == '9days':
    bar_cnt = 118

# %%
def calc_smoothness(data, type): 
    smoothness = []
    for i in range(data.shape[0]):
        row = np.array(data.iloc[i, :])
        # normalize row data, so that we could get comparable smoothness data 
        row = (row - min(row))/(max(row) - min(row)) 
        diff1 = row[1:] - row[:-1]
        diff2 = diff1[1:] - diff1[:-1]
        smth = sum(map(lambda x: x**2, diff2))
        smoothness.append(smth)
    return pd.Series(smoothness, name=type + '_smth', index=data.index)

# %%
def calc_derivative(data, name):
    derivatives = []
    for i in range(data.shape[0]):
        i_derivative = list(np.gradient(pd.Series(data.iloc[i,:]))/pd.Series(data.iloc[i,:]))
        derivatives.append(i_derivative)
    
    names = []
    for i in range(data.shape[1]):
        names.append(name + "_drv"+ str(i)) 
    
    return pd.DataFrame(derivatives, columns=names, index=data.index)

# %%
def calc_prc_chg(data, name):
    prc_chg = []
    for i in range(data.shape[0]):
        i_chg = list(data.iloc[i,:]/data.iloc[i, 0])
        prc_chg.append(i_chg)
    
    names = []
    for i in range(data.shape[1]):
        names.append(name + "_chg"+ str(i)) 
    
    return pd.DataFrame(prc_chg, columns=names, index=data.index)

# %%
def calc_level(data, name):
    
    level = []
    for i in range(data.shape[0]):
        max_num = max(data.iloc[i, :])
        min_num = min(data.iloc[i, :])
        level.append((data.iloc[i, -1] - min_num)/(max_num - min_num))
        
    return pd.Series(level, name = name + '_lev', index = data.index)

# %%
def normalize_data(data): 
    for i in range(data.shape[0]): 
        row = data.iloc[i, :] 
        data.iloc[i, :] = (row - min(row))/(max(row) - min(row)) 
    return data

# %%
def load_data():
    data = pd.DataFrame()
    
    for filename in os.listdir(file_path):
        if filename.endswith(".txt"): 
            tmp_df = pd.read_csv(os.path.join(file_path, filename), delimiter= '\s+', header = None)
            tmp_df = tmp_df.astype(float)
            tmp_df = tmp_df.iloc[20:,:]
            # column 180 data is wrong, so replace it with mean value of column 179 and 181
            # tmp_df[180] = (tmp_df[179] + tmp_df[181])/2    
            data = pd.concat([data, tmp_df])
    
    # remove duplicates 
    data = data.drop_duplicates()
    
    # remove extreme oscillator values 
    data = data[(data[0] > -7) & (data[0] < 7)] 
    
    # remove positive oscillator values
    # data = data[data[0] < 0]
    
    # reset index 
    data = data.reset_index(drop=True)
    
    # set column names 
    osc_names = ['osc' + str(i) for i in range(bar_cnt)]
    prc_names = ['prc' + str(i) for i in range(bar_cnt)]
    macd_names = ['macd' + str(i) for i in range(bar_cnt)]
    data.columns = osc_names + prc_names + macd_names + ['rtn']
    
    # preprocess oscillator data 
    osc_data = data.iloc[:, :bar_cnt].reset_index(drop=True)
    osc_data = osc_data[osc_data.columns[::-1]]
    osc_smth = calc_smoothness(osc_data, 'osc')   # add oscillator smoothness feature 
    osc_lev = calc_level(osc_data, 'osc')   # calculate relative oscillator level 
    # benchmark oscillator values on the oldest one 
    for i in range(osc_data.shape[0]):
        osc_data.iloc[i, :] = osc_data.iloc[i, :] - osc_data.iloc[i, 0] 
    
    # preprocess price data 
    prc_data = data.iloc[:, bar_cnt:bar_cnt*2].reset_index(drop=True)
    prc_data = prc_data[prc_data.columns[::-1]]
    prc_smth = calc_smoothness(prc_data, 'prc')  # add price smoothness feature
    prc_lev = calc_level(prc_data, 'prc')   # calculate relative price level 
    prc_drv = calc_derivative(prc_data, 'prc')   # calculate price derivatives 
    prc_chg = calc_prc_chg(prc_data, 'prc')
    
    # preprocess MACD data 
    macd_data = data.iloc[:, bar_cnt*2:bar_cnt*3].reset_index(drop=True)
    macd_data = macd_data[macd_data.columns[::-1]]
    macd_smth = calc_smoothness(macd_data, 'macd')   # add macd smoothness feature
    macd_lev = calc_level(macd_data, 'macd')    # calculate relative macd level 
    macd_data = normalize_data(macd_data)    # normalize macd data 
    
    rtn = data['rtn'].reset_index(drop=True)
    label = pd.Series(map(lambda x: 1 if x>0 else 0, rtn), name = 'label')
    
    data = pd.concat([osc_data, osc_smth, osc_lev,
                      prc_drv, prc_chg, prc_smth, prc_lev, 
                      macd_data, macd_smth, macd_lev, 
                      rtn, label], axis=1)
    data = data.reset_index(drop=True)
    
    return data

# %%
class StockData():
    def __init__(self, data):
        
        # balance the data set 
        pos_data = data[data['label'] == 1]
        neg_data = data[data['label'] == 0]
        if pos_data.shape[0] > neg_data.shape[0]:
            pos_data = pos_data.sample(neg_data.shape[0])
        else:
            neg_data = neg_data.sample(pos_data.shape[0])
        data = pd.concat([pos_data, neg_data], axis = 0)
        data = data.reset_index(drop = True) 
        
        X = data.iloc[:, :-1]
        y = data['label']
        
        X_train_valid_w_rtn, X_test_w_rtn, y_train_valid, y_test = train_test_split(X, y, test_size=0.25) 
        # train_valid set
        self.train_valid_rtn = X_train_valid_w_rtn['rtn']
        self.X_train_valid = X_train_valid_w_rtn.drop(['rtn'], axis = 1)
        self.y_train_valid = y_train_valid
        
        X_train_w_rtn, X_valid_w_rtn, y_train, y_valid = train_test_split(X_train_valid_w_rtn, y_train_valid, test_size=0.25) 
        # training set 
        self.train_rtn = X_train_w_rtn['rtn'] 
        self.X_train = X_train_w_rtn.drop(['rtn'], axis = 1)
        self.y_train = y_train
        # validation set
        self.valid_rtn = X_valid_w_rtn['rtn']
        self.X_valid = X_valid_w_rtn.drop(['rtn'], axis = 1) 
        self.y_valid = y_valid
        # test set 
        self.test_rtn = X_test_w_rtn['rtn']
        self.X_test = X_test_w_rtn.drop(['rtn'], axis = 1)        
        self.y_test = y_test

# %%
data = load_data()
data.shape
# Out:
# (100987, 172)

# %%
data.to_csv(file_path + 'data_XGB1.csv')

# %%
data = pd.read_csv(file_path + 'data_XGB1.csv', header=0, index_col=0)
data.shape
# Out:
# (100987, 172)

# %%
data = data.sample(12000)
data.shape
# Out:
# (12000, 172)

# %%
data.head()
# Out:
#        osc40  osc39  osc38  osc37  osc36  osc35  osc34  osc33  osc32  osc31  \
# 27921    0.0   0.20   0.46   0.80   1.20   1.59   2.00   2.13   2.23   2.34
# 36720    0.0   0.16   0.44   0.53   0.73   0.77   0.93   1.01   1.13   1.07
# 32576    0.0   0.17   0.29   0.41   0.31   0.33   0.32   0.25   0.03  -0.34
# 16850    0.0  -0.16  -0.39  -0.65  -0.85  -0.92  -1.04  -1.04  -1.06  -0.97
# 25459    0.0   0.01  -0.02  -0.06  -0.12  -0.05  -0.01   0.03   0.07   0.06
#
#        ...     macd5     macd4     macd3     macd2     macd1     macd0  \
# 27921  ...  0.905501  0.991537  1.000000  0.911142  0.819464  0.897038
# 36720  ...  0.415547  0.422265  0.389635  0.359885  0.307102  0.366603
# 32576  ...  0.400000  0.300000  0.300000  0.200000  0.200000  0.300000
# 16850  ...  0.352941  0.250000  0.485294  0.602941  0.647059  0.617647
# 25459  ...  0.710526  0.763158  0.842105  0.815789  0.736842  0.684211
#
#        macd_smth  macd_lev   rtn  label
# 27921   0.293090  0.897038  1.36      1
# 36720   0.298496  0.366603 -1.41      0
# 32576   0.420000  0.300000  0.00      0
# 16850   0.420631  0.617647 -0.30      0
# 25459   0.257618  0.684211  0.17      1
#
# [5 rows x 172 columns]

# %%
stock_data = StockData(data)

print(stock_data.X_train.shape)
print(stock_data.X_valid.shape)
print(stock_data.X_test.shape)
# Out:
# (5486, 170)
# (1829, 170)
# (2439, 170)

# %%
depths = [4*i for i in range(2, 21)]
estimators = [10*i for i in range(5, 21)] 
results = []
for d in depths:
    row = [d]
    for e in estimators:
        start = time.time() 
        clf = XGBClassifier(max_depth=d, n_estimators=e)
        clf.fit(stock_data.X_train, stock_data.y_train) 
        valid_score = np.round(clf.score(stock_data.X_valid, stock_data.y_valid), 4)
        row.append(valid_score)
        end = time.time()
        print("max_depth = {}, n_estimators = {}, validation score = {}, run time = {}".format(d, e, valid_score, start-end))
    results.append(row)
# Out:
# max_depth = 8, n_estimators = 50, validation score = 0.491, run time = -14.678264856338501
# max_depth = 8, n_estimators = 60, validation score = 0.4926, run time = -16.947750329971313
# max_depth = 8, n_estimators = 70, validation score = 0.4877, run time = -18.795708417892456
# max_depth = 8, n_estimators = 80, validation score = 0.503, run time = -18.398114681243896
# max_depth = 8, n_estimators = 90, validation score = 0.5036, run time = -26.051838636398315
# max_depth = 8, n_estimators = 100, validation score = 0.5118, run time = -25.49998927116394
# max_depth = 8, n_estimators = 110, validation score = 0.5107, run time = -32.863261222839355
# max_depth = 8, n_estimators = 120, validation score = 0.509, run time = -32.711719274520874
# max_depth = 8, n_estimators = 130, validation score = 0.5036, run time = -69.05991077423096
# max_depth = 8, n_estimators = 140, validation score = 0.503, run time = -44.18846774101257
# max_depth = 8, n_estimators = 150, validation score = 0.5014, run time = -48.15799403190613
# max_depth = 8, n_estimators = 160, validation score = 0.5057, run time = -42.79676413536072
# max_depth = 8, n_estimators = 170, validation score = 0.4992, run time = -45.68990874290466
# max_depth = 8, n_estimators = 180, validation score = 0.5003, run time = -48.00567388534546
# max_depth = 8, n_estimators = 190, validation score = 0.5014, run time = -48.60612225532532
# max_depth = 8, n_estimators = 200, validation score = 0.4997, run time = -50.973445653915405
# max_depth = 12, n_estimators = 50, validation score = 0.5052, run time = -20.61100149154663
# max_depth = 12, n_estimators = 60, validation score = 0.5134, run time = -24.411998987197876
# max_depth = 12, n_estimators = 70, validation score = 0.5139, run time = -28.391125917434692
# max_depth = 12, n_estimators = 80, validation score = 0.5145, run time = -31.67549753189087
# max_depth = 12, n_estimators = 90, validation score = 0.5145, run time = -34.654000997543335
# max_depth = 12, n_estimators = 100, validation score = 0.5085, run time = -40.64195394515991
# max_depth = 12, n_estimators = 110, validation score = 0.5079, run time = -45.175042152404785
# max_depth = 12, n_estimators = 120, validation score = 0.5101, run time = -51.77984261512756
# max_depth = 12, n_estimators = 130, validation score = 0.5052, run time = -42.2279257774353
# max_depth = 12, n_estimators = 140, validation score = 0.5052, run time = -57.73329210281372
# max_depth = 12, n_estimators = 150, validation score = 0.5107, run time = -54.351038217544556
# max_depth = 12, n_estimators = 160, validation score = 0.5074, run time = -66.44115495681763
# max_depth = 12, n_estimators = 170, validation score = 0.5057, run time = -74.20296597480774
# max_depth = 12, n_estimators = 180, validation score = 0.5041, run time = -73.38387846946716
# max_depth = 12, n_estimators = 190, validation score = 0.5046, run time = -64.72213411331177
# max_depth = 12, n_estimators = 200, validation score = 0.5112, run time = -63.71110820770264
# max_depth = 16, n_estimators = 50, validation score = 0.5074, run time = -24.075225353240967
# max_depth = 16, n_estimators = 60, validation score = 0.5128, run time = -29.74987268447876
# max_depth = 16, n_estimators = 70, validation score = 0.5101, run time = -39.35085582733154
# max_depth = 16, n_estimators = 80, validation score = 0.5112, run time = -44.43364500999451
# max_depth = 16, n_estimators = 90, validation score = 0.5139, run time = -44.68172574043274
# max_depth = 16, n_estimators = 100, validation score = 0.5112, run time = -55.09597373008728
# max_depth = 16, n_estimators = 110, validation score = 0.5145, run time = -55.93653607368469
# max_depth = 16, n_estimators = 120, validation score = 0.5134, run time = -61.53867244720459
# max_depth = 16, n_estimators = 130, validation score = 0.5036, run time = -66.59389758110046
# max_depth = 16, n_estimators = 140, validation score = 0.5085, run time = -78.33177518844604
# max_depth = 16, n_estimators = 150, validation score = 0.5085, run time = -71.0332453250885
# max_depth = 16, n_estimators = 160, validation score = 0.5063, run time = -80.11710214614868
# max_depth = 16, n_estimators = 170, validation score = 0.5118, run time = -77.01980829238892
# max_depth = 16, n_estimators = 180, validation score = 0.5096, run time = -83.77334928512573
# max_depth = 16, n_estimators = 190, validation score = 0.5118, run time = -87.80677437782288
# max_depth = 16, n_estimators = 200, validation score = 0.5134, run time = -94.19453549385071
# max_depth = 20, n_estimators = 50, validation score = 0.5205, run time = -31.843043088912964
# max_depth = 20, n_estimators = 60, validation score = 0.5216, run time = -37.512991428375244
# max_depth = 20, n_estimators = 70, validation score = 0.5178, run time = -40.504955530166626
# max_depth = 20, n_estimators = 80, validation score = 0.5221, run time = -50.12299036979675
# max_depth = 20, n_estimators = 90, validation score = 0.5221, run time = -53.29436445236206
# max_depth = 20, n_estimators = 100, validation score = 0.52, run time = -60.21726179122925
# max_depth = 20, n_estimators = 110, validation score = 0.5194, run time = -58.209494829177856
# max_depth = 20, n_estimators = 120, validation score = 0.5189, run time = -74.20125198364258
# max_depth = 20, n_estimators = 130, validation score = 0.5221, run time = -74.21995329856873
# max_depth = 20, n_estimators = 140, validation score = 0.5183, run time = -79.31204223632812
# max_depth = 20, n_estimators = 150, validation score = 0.5194, run time = -82.9049699306488
# max_depth = 20, n_estimators = 160, validation score = 0.52, run time = -83.62223696708679
# max_depth = 20, n_estimators = 170, validation score = 0.5243, run time = -87.69988894462585
# max_depth = 20, n_estimators = 180, validation score = 0.5232, run time = -95.90968322753906
# max_depth = 20, n_estimators = 190, validation score = 0.5216, run time = -96.93420076370239
# max_depth = 20, n_estimators = 200, validation score = 0.5243, run time = -103.65064644813538
# max_depth = 24, n_estimators = 50, validation score = 0.5123, run time = -33.10299348831177
# max_depth = 24, n_estimators = 60, validation score = 0.5118, run time = -40.20800709724426
# max_depth = 24, n_estimators = 70, validation score = 0.515, run time = -46.025503396987915
# max_depth = 24, n_estimators = 80, validation score = 0.5068, run time = -50.41434073448181
# max_depth = 24, n_estimators = 90, validation score = 0.5123, run time = -57.25634765625
# max_depth = 24, n_estimators = 100, validation score = 0.509, run time = -64.5562195777893
# max_depth = 24, n_estimators = 110, validation score = 0.5074, run time = -69.85347032546997
# max_depth = 24, n_estimators = 120, validation score = 0.5183, run time = -71.58799648284912
# max_depth = 24, n_estimators = 130, validation score = 0.5118, run time = -75.75940775871277
# max_depth = 24, n_estimators = 140, validation score = 0.5161, run time = -85.34803771972656
# max_depth = 24, n_estimators = 150, validation score = 0.5145, run time = -87.51412510871887
# max_depth = 24, n_estimators = 160, validation score = 0.5178, run time = -95.67925429344177
# max_depth = 24, n_estimators = 170, validation score = 0.5194, run time = -94.98908591270447
# max_depth = 24, n_estimators = 180, validation score = 0.52, run time = -100.36070036888123
# max_depth = 24, n_estimators = 190, validation score = 0.5161, run time = -102.86027216911316
# max_depth = 24, n_estimators = 200, validation score = 0.521, run time = -107.23093581199646
# max_depth = 28, n_estimators = 50, validation score = 0.5221, run time = -35.246002435684204
# max_depth = 28, n_estimators = 60, validation score = 0.5227, run time = -42.91954183578491
# max_depth = 28, n_estimators = 70, validation score = 0.5156, run time = -48.35416126251221
# max_depth = 28, n_estimators = 80, validation score = 0.52, run time = -54.913742780685425
# max_depth = 28, n_estimators = 90, validation score = 0.5205, run time = -59.00800156593323
# max_depth = 28, n_estimators = 100, validation score = 0.5221, run time = -65.32419109344482
# max_depth = 28, n_estimators = 110, validation score = 0.5227, run time = -70.92500686645508
# max_depth = 28, n_estimators = 120, validation score = 0.5227, run time = -75.67406105995178
# max_depth = 28, n_estimators = 130, validation score = 0.5221, run time = -78.46981692314148
# max_depth = 28, n_estimators = 140, validation score = 0.5249, run time = -84.6555106639862
# max_depth = 28, n_estimators = 150, validation score = 0.5216, run time = -89.16725873947144
# max_depth = 28, n_estimators = 160, validation score = 0.5227, run time = -93.6120297908783
# max_depth = 28, n_estimators = 170, validation score = 0.5227, run time = -97.32328343391418
# max_depth = 28, n_estimators = 180, validation score = 0.5221, run time = -104.222829580307
# max_depth = 28, n_estimators = 190, validation score = 0.5205, run time = -105.11792945861816
# max_depth = 28, n_estimators = 200, validation score = 0.5189, run time = -109.04696941375732
# max_depth = 32, n_estimators = 50, validation score = 0.4992, run time = -36.92799782752991
# max_depth = 32, n_estimators = 60, validation score = 0.5107, run time = -44.168410539627075
# max_depth = 32, n_estimators = 70, validation score = 0.5101, run time = -48.74819588661194
# max_depth = 32, n_estimators = 80, validation score = 0.5128, run time = -54.73957180976868
# max_depth = 32, n_estimators = 90, validation score = 0.5128, run time = -59.40500545501709
# max_depth = 32, n_estimators = 100, validation score = 0.5134, run time = -64.48337411880493
# max_depth = 32, n_estimators = 110, validation score = 0.509, run time = -69.41446661949158
# max_depth = 32, n_estimators = 120, validation score = 0.5068, run time = -73.49799752235413
# max_depth = 32, n_estimators = 130, validation score = 0.509, run time = -76.57597923278809
# max_depth = 32, n_estimators = 140, validation score = 0.5074, run time = -86.18674874305725
# max_depth = 32, n_estimators = 150, validation score = 0.5096, run time = -87.9765236377716
# max_depth = 32, n_estimators = 160, validation score = 0.5139, run time = -93.61995577812195
# max_depth = 32, n_estimators = 170, validation score = 0.515, run time = -95.81456732749939
# max_depth = 32, n_estimators = 180, validation score = 0.5112, run time = -105.29805302619934
# max_depth = 32, n_estimators = 190, validation score = 0.5107, run time = -107.17898082733154
# max_depth = 32, n_estimators = 200, validation score = 0.5101, run time = -95.26407432556152
# max_depth = 36, n_estimators = 50, validation score = 0.5025, run time = -23.939006328582764
# max_depth = 36, n_estimators = 60, validation score = 0.5046, run time = -43.10787081718445
# max_depth = 36, n_estimators = 70, validation score = 0.5063, run time = -47.2299907207489
# max_depth = 36, n_estimators = 80, validation score = 0.5074, run time = -53.99879503250122
# max_depth = 36, n_estimators = 90, validation score = 0.5128, run time = -58.50399827957153
# max_depth = 36, n_estimators = 100, validation score = 0.503, run time = -63.49074363708496
# max_depth = 36, n_estimators = 110, validation score = 0.515, run time = -67.98267698287964
# max_depth = 36, n_estimators = 120, validation score = 0.5123, run time = -72.29655361175537
# max_depth = 36, n_estimators = 130, validation score = 0.5134, run time = -77.50682020187378
# max_depth = 36, n_estimators = 140, validation score = 0.5238, run time = -79.62713837623596
# max_depth = 36, n_estimators = 150, validation score = 0.5232, run time = -84.4830002784729
# max_depth = 36, n_estimators = 160, validation score = 0.5194, run time = -89.19699025154114
# max_depth = 36, n_estimators = 170, validation score = 0.5243, run time = -93.36761355400085
# max_depth = 36, n_estimators = 180, validation score = 0.5194, run time = -99.51777195930481
# max_depth = 36, n_estimators = 190, validation score = 0.5205, run time = -103.79695081710815
# max_depth = 36, n_estimators = 200, validation score = 0.5232, run time = -107.58069491386414
# max_depth = 40, n_estimators = 50, validation score = 0.5025, run time = -35.510019063949585
# max_depth = 40, n_estimators = 60, validation score = 0.5046, run time = -43.597198724746704
# max_depth = 40, n_estimators = 70, validation score = 0.5063, run time = -48.91900134086609
# max_depth = 40, n_estimators = 80, validation score = 0.5074, run time = -54.97773051261902
# max_depth = 40, n_estimators = 90, validation score = 0.5128, run time = -59.15744423866272
# max_depth = 40, n_estimators = 100, validation score = 0.503, run time = -59.33485436439514
# max_depth = 40, n_estimators = 110, validation score = 0.515, run time = -64.20397520065308
# max_depth = 40, n_estimators = 120, validation score = 0.5123, run time = -72.01504516601562
# max_depth = 40, n_estimators = 130, validation score = 0.5134, run time = -68.9943516254425
# max_depth = 40, n_estimators = 140, validation score = 0.5238, run time = -76.18300580978394
# max_depth = 40, n_estimators = 150, validation score = 0.5232, run time = -82.65600323677063
# max_depth = 40, n_estimators = 160, validation score = 0.5194, run time = -80.64703750610352
# max_depth = 40, n_estimators = 170, validation score = 0.5243, run time = -83.3149962425232
# max_depth = 40, n_estimators = 180, validation score = 0.5194, run time = -87.5909960269928
# max_depth = 40, n_estimators = 190, validation score = 0.5205, run time = -92.02467560768127
# max_depth = 40, n_estimators = 200, validation score = 0.5232, run time = -94.70564341545105
# max_depth = 44, n_estimators = 50, validation score = 0.5025, run time = -31.398504734039307
# max_depth = 44, n_estimators = 60, validation score = 0.5046, run time = -36.72199511528015
# max_depth = 44, n_estimators = 70, validation score = 0.5063, run time = -42.623098611831665
# max_depth = 44, n_estimators = 80, validation score = 0.5074, run time = -46.73300743103027
# max_depth = 44, n_estimators = 90, validation score = 0.5128, run time = -52.534143686294556
# max_depth = 44, n_estimators = 100, validation score = 0.503, run time = -56.187047481536865
# max_depth = 44, n_estimators = 110, validation score = 0.515, run time = -60.425966024398804
# max_depth = 44, n_estimators = 120, validation score = 0.5123, run time = -65.0989990234375
# max_depth = 44, n_estimators = 130, validation score = 0.5134, run time = -69.75911092758179
# max_depth = 44, n_estimators = 140, validation score = 0.5238, run time = -73.12100172042847
# max_depth = 44, n_estimators = 150, validation score = 0.5232, run time = -77.24773979187012
# max_depth = 44, n_estimators = 160, validation score = 0.5194, run time = -80.77297377586365
# max_depth = 44, n_estimators = 170, validation score = 0.5243, run time = -84.58794736862183
# max_depth = 44, n_estimators = 180, validation score = 0.5194, run time = -88.07256197929382
# max_depth = 44, n_estimators = 190, validation score = 0.5205, run time = -92.92599630355835
# max_depth = 44, n_estimators = 200, validation score = 0.5232, run time = -90.80037689208984
# max_depth = 48, n_estimators = 50, validation score = 0.5025, run time = -29.67369508743286
# max_depth = 48, n_estimators = 60, validation score = 0.5046, run time = -23.924236297607422
# max_depth = 48, n_estimators = 70, validation score = 0.5063, run time = -21.856997966766357
# max_depth = 48, n_estimators = 80, validation score = 0.5074, run time = -24.14700150489807
# max_depth = 48, n_estimators = 90, validation score = 0.5128, run time = -24.30999732017517
# max_depth = 48, n_estimators = 100, validation score = 0.503, run time = -32.37010955810547
# max_depth = 48, n_estimators = 110, validation score = 0.515, run time = -33.57799434661865
# max_depth = 48, n_estimators = 120, validation score = 0.5123, run time = -31.627999305725098
# max_depth = 48, n_estimators = 130, validation score = 0.5134, run time = -32.83609390258789
# max_depth = 48, n_estimators = 140, validation score = 0.5238, run time = -37.197001457214355
# max_depth = 48, n_estimators = 150, validation score = 0.5232, run time = -36.47899532318115
# max_depth = 48, n_estimators = 160, validation score = 0.5194, run time = -36.170997619628906
# max_depth = 48, n_estimators = 170, validation score = 0.5243, run time = -42.37300181388855
# max_depth = 48, n_estimators = 180, validation score = 0.5194, run time = -42.51700186729431
# max_depth = 48, n_estimators = 190, validation score = 0.5205, run time = -52.94800066947937
# max_depth = 48, n_estimators = 200, validation score = 0.5232, run time = -63.367610931396484
# max_depth = 52, n_estimators = 50, validation score = 0.5025, run time = -19.959006547927856
# max_depth = 52, n_estimators = 60, validation score = 0.5046, run time = -19.801998615264893
# max_depth = 52, n_estimators = 70, validation score = 0.5063, run time = -22.03700065612793
# max_depth = 52, n_estimators = 80, validation score = 0.5074, run time = -24.737998485565186
# max_depth = 52, n_estimators = 90, validation score = 0.5128, run time = -26.908003568649292
# max_depth = 52, n_estimators = 100, validation score = 0.503, run time = -27.376036643981934
# max_depth = 52, n_estimators = 110, validation score = 0.515, run time = -27.512962341308594
# max_depth = 52, n_estimators = 120, validation score = 0.5123, run time = -34.09699845314026
# max_depth = 52, n_estimators = 130, validation score = 0.5134, run time = -35.117997884750366
# max_depth = 52, n_estimators = 140, validation score = 0.5238, run time = -33.81100344657898
# max_depth = 52, n_estimators = 150, validation score = 0.5232, run time = -37.53400278091431
# max_depth = 52, n_estimators = 160, validation score = 0.5194, run time = -41.74099540710449
# max_depth = 52, n_estimators = 170, validation score = 0.5243, run time = -44.18826723098755
# max_depth = 52, n_estimators = 180, validation score = 0.5194, run time = -45.85300064086914
# max_depth = 52, n_estimators = 190, validation score = 0.5205, run time = -44.321003437042236
# max_depth = 52, n_estimators = 200, validation score = 0.5232, run time = -42.65999746322632
# max_depth = 56, n_estimators = 50, validation score = 0.5025, run time = -16.099998235702515
# max_depth = 56, n_estimators = 60, validation score = 0.5046, run time = -19.120001077651978
# max_depth = 56, n_estimators = 70, validation score = 0.5063, run time = -21.505003452301025
# max_depth = 56, n_estimators = 80, validation score = 0.5074, run time = -21.05099654197693
# max_depth = 56, n_estimators = 90, validation score = 0.5128, run time = -22.972000122070312
# max_depth = 56, n_estimators = 100, validation score = 0.503, run time = -26.210001230239868
# max_depth = 56, n_estimators = 110, validation score = 0.515, run time = -31.404001474380493
# max_depth = 56, n_estimators = 120, validation score = 0.5123, run time = -31.286996364593506
# max_depth = 56, n_estimators = 130, validation score = 0.5134, run time = -30.59000563621521
# max_depth = 56, n_estimators = 140, validation score = 0.5238, run time = -34.77299737930298
# max_depth = 56, n_estimators = 150, validation score = 0.5232, run time = -39.80999970436096
# max_depth = 56, n_estimators = 160, validation score = 0.5194, run time = -41.71400046348572
# max_depth = 56, n_estimators = 170, validation score = 0.5243, run time = -43.56800150871277
# max_depth = 56, n_estimators = 180, validation score = 0.5194, run time = -44.450002908706665
# max_depth = 56, n_estimators = 190, validation score = 0.5205, run time = -40.933995485305786
# max_depth = 56, n_estimators = 200, validation score = 0.5232, run time = -46.530001163482666
# max_depth = 60, n_estimators = 50, validation score = 0.5025, run time = -16.00700092315674
# max_depth = 60, n_estimators = 60, validation score = 0.5046, run time = -17.61800527572632
# max_depth = 60, n_estimators = 70, validation score = 0.5063, run time = -18.616999864578247
# max_depth = 60, n_estimators = 80, validation score = 0.5074, run time = -20.958995819091797
# max_depth = 60, n_estimators = 90, validation score = 0.5128, run time = -24.770997047424316
# max_depth = 60, n_estimators = 100, validation score = 0.503, run time = -29.014999628067017
# max_depth = 60, n_estimators = 110, validation score = 0.515, run time = -37.99399995803833
# max_depth = 60, n_estimators = 120, validation score = 0.5123, run time = -35.13100290298462
# max_depth = 60, n_estimators = 130, validation score = 0.5134, run time = -35.41900157928467
# max_depth = 60, n_estimators = 140, validation score = 0.5238, run time = -37.65099740028381
# max_depth = 60, n_estimators = 150, validation score = 0.5232, run time = -33.84299898147583
# max_depth = 60, n_estimators = 160, validation score = 0.5194, run time = -37.663997411727905
# max_depth = 60, n_estimators = 170, validation score = 0.5243, run time = -41.909000635147095
# max_depth = 60, n_estimators = 180, validation score = 0.5194, run time = -38.20799922943115
# max_depth = 60, n_estimators = 190, validation score = 0.5205, run time = -42.744998931884766
# max_depth = 60, n_estimators = 200, validation score = 0.5232, run time = -46.022016763687134
# max_depth = 64, n_estimators = 50, validation score = 0.5025, run time = -13.668053150177002
# max_depth = 64, n_estimators = 60, validation score = 0.5046, run time = -16.242950439453125
# max_depth = 64, n_estimators = 70, validation score = 0.5063, run time = -18.26699662208557
# max_depth = 64, n_estimators = 80, validation score = 0.5074, run time = -23.011000633239746
# max_depth = 64, n_estimators = 90, validation score = 0.5128, run time = -26.074000120162964
# max_depth = 64, n_estimators = 100, validation score = 0.503, run time = -28.226000547409058
# max_depth = 64, n_estimators = 110, validation score = 0.515, run time = -30.996002912521362
# max_depth = 64, n_estimators = 120, validation score = 0.5123, run time = -32.41799807548523
# max_depth = 64, n_estimators = 130, validation score = 0.5134, run time = -35.09500193595886
# max_depth = 64, n_estimators = 140, validation score = 0.5238, run time = -32.58500099182129
# max_depth = 64, n_estimators = 150, validation score = 0.5232, run time = -33.57999873161316
# max_depth = 64, n_estimators = 160, validation score = 0.5194, run time = -40.66300320625305
# max_depth = 64, n_estimators = 170, validation score = 0.5243, run time = -39.46200227737427
# max_depth = 64, n_estimators = 180, validation score = 0.5194, run time = -38.29699635505676
# max_depth = 64, n_estimators = 190, validation score = 0.5205, run time = -45.613218545913696
# max_depth = 64, n_estimators = 200, validation score = 0.5232, run time = -43.28299832344055
# max_depth = 68, n_estimators = 50, validation score = 0.5025, run time = -13.651001930236816
# max_depth = 68, n_estimators = 60, validation score = 0.5046, run time = -16.08500027656555
# max_depth = 68, n_estimators = 70, validation score = 0.5063, run time = -20.087000846862793
# max_depth = 68, n_estimators = 80, validation score = 0.5074, run time = -22.64299988746643
# max_depth = 68, n_estimators = 90, validation score = 0.5128, run time = -25.1889967918396
# max_depth = 68, n_estimators = 100, validation score = 0.503, run time = -27.961997747421265
# max_depth = 68, n_estimators = 110, validation score = 0.515, run time = -28.50901174545288
# max_depth = 68, n_estimators = 120, validation score = 0.5123, run time = -32.12598991394043
# max_depth = 68, n_estimators = 130, validation score = 0.5134, run time = -32.60599946975708
# max_depth = 68, n_estimators = 140, validation score = 0.5238, run time = -31.298001050949097
# max_depth = 68, n_estimators = 150, validation score = 0.5232, run time = -34.16399669647217
# max_depth = 68, n_estimators = 160, validation score = 0.5194, run time = -39.25300431251526
# max_depth = 68, n_estimators = 170, validation score = 0.5243, run time = -36.76100301742554
# max_depth = 68, n_estimators = 180, validation score = 0.5194, run time = -38.068997621536255
# max_depth = 68, n_estimators = 190, validation score = 0.5205, run time = -44.692888259887695
# max_depth = 68, n_estimators = 200, validation score = 0.5232, run time = -46.3899986743927
# max_depth = 72, n_estimators = 50, validation score = 0.5025, run time = -15.423999071121216
# max_depth = 72, n_estimators = 60, validation score = 0.5046, run time = -17.177000761032104
# max_depth = 72, n_estimators = 70, validation score = 0.5063, run time = -20.775003910064697
# max_depth = 72, n_estimators = 80, validation score = 0.5074, run time = -23.163997173309326
# max_depth = 72, n_estimators = 90, validation score = 0.5128, run time = -22.87799859046936
# max_depth = 72, n_estimators = 100, validation score = 0.503, run time = -24.055999279022217
# max_depth = 72, n_estimators = 110, validation score = 0.515, run time = -26.58400535583496
# max_depth = 72, n_estimators = 120, validation score = 0.5123, run time = -31.423998594284058
# max_depth = 72, n_estimators = 130, validation score = 0.5134, run time = -31.906005382537842
# max_depth = 72, n_estimators = 140, validation score = 0.5238, run time = -31.363998651504517
# max_depth = 72, n_estimators = 150, validation score = 0.5232, run time = -34.772000551223755
# max_depth = 72, n_estimators = 160, validation score = 0.5194, run time = -40.8600013256073
# max_depth = 72, n_estimators = 170, validation score = 0.5243, run time = -37.838001012802124
# max_depth = 72, n_estimators = 180, validation score = 0.5194, run time = -39.542999505996704
# max_depth = 72, n_estimators = 190, validation score = 0.5205, run time = -44.330000162124634
# max_depth = 72, n_estimators = 200, validation score = 0.5232, run time = -46.72899889945984
# max_depth = 76, n_estimators = 50, validation score = 0.5025, run time = -14.35799527168274
# max_depth = 76, n_estimators = 60, validation score = 0.5046, run time = -18.40499997138977
# max_depth = 76, n_estimators = 70, validation score = 0.5063, run time = -20.959999561309814
# max_depth = 76, n_estimators = 80, validation score = 0.5074, run time = -23.284998178482056
# max_depth = 76, n_estimators = 90, validation score = 0.5128, run time = -22.32699990272522
# max_depth = 76, n_estimators = 100, validation score = 0.503, run time = -24.285001277923584

# %%
col_names = ['est=' + str(i) for i in estimators]
col_names.insert(0, 'depth')
results = pd.DataFrame(results, columns=col_names)

# %%
clf = XGBClassifier() 
estimators = [10*i for i in range(5, 21)] 
depths = [4*i for i in range(2, 21)]
parameters = {'n_estimators':estimators, 'max_depth': depths} 
gs = GridSearchCV(clf, parameters, cv=5)
gs.fit(stock_data.X_train_valid, stock_data.y_train_valid)
print(gs.best_params_)
print(gs.best_score_)
print(gs.score(stock_data.X_test, stock_data.y_test))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-6d3473ab20c0> in <module>
#       4 parameters = {'n_estimators':estimators, 'max_depth': depths}
#       5 gs = GridSearchCV(clf, parameters, cv=5)
# ----> 6 gs.fit(stock_data.X_train_valid, stock_data.y_train_valid)
#       7 print(gs.best_params_)
#       8 print(gs.best_score_)
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     720                 return results_container[0]
#     721
# --> 722             self._run_search(evaluate_candidates)
#     723
#     724         results = results_container[0]
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1189     def _run_search(self, evaluate_candidates):
#    1190         """Search all candidates in param_grid"""
# -> 1191         evaluate_candidates(ParameterGrid(self.param_grid))
#    1192
#    1193
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params)
#     709                                for parameters, (train, test)
#     710                                in product(candidate_params,
# --> 711                                           cv.split(X, y, groups)))
#     712
#     713                 all_candidate_params.extend(candidate_params)
#
# ~\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in __call__(self, iterable)
#     918                 self._iterating = self._original_iterator is not None
#     919
# --> 920             while self.dispatch_one_batch(iterator):
#     921                 pass
#     922
#
# ~\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# ~\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# ~\Anaconda3\lib\site-packages\sklearn\externals\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~\Anaconda3\lib\site-packages\sklearn\externals\joblib\_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# ~\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     526             estimator.fit(X_train, **fit_params)
#     527         else:
# --> 528             estimator.fit(X_train, y_train, **fit_params)
#     529
#     530     except Exception as e:
#
# ~\Anaconda3\lib\site-packages\xgboost\sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set)
#     589                               early_stopping_rounds=early_stopping_rounds,
#     590                               evals_result=evals_result, obj=obj, feval=feval,
# --> 591                               verbose_eval=verbose, xgb_model=None)
#     592
#     593         self.objective = xgb_options["objective"]
#
# ~\Anaconda3\lib\site-packages\xgboost\training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     208                            evals=evals,
#     209                            obj=obj, feval=feval,
# --> 210                            xgb_model=xgb_model, callbacks=callbacks)
#     211
#     212
#
# ~\Anaconda3\lib\site-packages\xgboost\training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      72         # Skip the first update if it is a recovery step.
#      73         if version % 2 == 0:
# ---> 74             bst.update(dtrain, i, obj)
#      75             bst.save_rabit_checkpoint()
#      76             version += 1
#
# ~\Anaconda3\lib\site-packages\xgboost\core.py in update(self, dtrain, iteration, fobj)
#    1019         if fobj is None:
#    1020             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, ctypes.c_int(iteration),
# -> 1021                                                     dtrain.handle))
#    1022         else:
#    1023             pred = self.predict(dtrain)
#
# KeyboardInterrupt:
